# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv(r'C:\Users\nabih\Downloads\movies.csv',encoding = "ISO-8859-1")
df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.isnull().sum() #check for missing values
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
for col in df.columns: #show null values in percentage form using numpy
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %% [markdown]
# # EXPLORE DATA & CLEANING

# %%
df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
#budget and gross aren't needed to be in float 
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#year and released year should be same but it's not the case 
# to do this, create a new column
df['CorrectYear'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#          budget  company  country  director  genre      gross  name  rating  \
# 6380  245000000     1428       54      1037      0  936662225  4679       7
# 5061  237000000     2062       53      1066      0  760507625   501       7
# 2420  200000000     2062       54      1066      6  658672302  6177       7
# 6391  150000000     2085       54       466      0  652270625  2721       7
# 5723  220000000     1491       54      1412      0  623357910  4995       7
#
#       released  runtime  score  star    votes  writer  year CorrectYear
# 6380      2290      136    8.1   475   687192    2356  2015        2290
# 5061      1800      162    7.8  2084   954412    1629  2009        1800
# 2420       910      194    7.8  1444   862554    1629  1997         910
# 6391      2247      124    7.0   404   469200    3310  2015        2247
# 5723      1987      143    8.1  2001  1064633    2145  2012        1987

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False) #sort data in deascending order movies having highest gross apear at first

# %%
#fyi: to drop duplicates you maay use method drop_duplicates

# %% [markdown]
# # FINDING CORRELATION BETWEEN ATTR with visualization

# %%
#Budget will have high correlation with movie revenue
# Scatter budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Correlation')
plt.xlabel('Gross Earning')
plt.ylabel('Budget')
plt.show()

# %%
#seaborn for regression plot to check if it's correlated
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})

# %%
#correlation list for numerical fields
df.corr() #three types of correlations Pearson,Kendall,Spearman. this one is pearson, default one with slightly diff results
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
df.corr(method='kendall')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.523459  0.164816 -0.019526  0.451137  0.214114
# gross    0.523459  1.000000  0.139270  0.033163  0.479772  0.098585
# runtime  0.164816  0.139270  1.000000  0.282068  0.195640  0.073785
# score   -0.019526  0.033163  0.282068  1.000000  0.272967  0.070451
# votes    0.451137  0.479772  0.195640  0.272967  1.000000  0.339625
# year     0.214114  0.098585  0.073785  0.070451  0.339625  1.000000

# %%
df.corr(method='spearman')
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.698639  0.231672 -0.027868  0.616419  0.300553
# gross    0.698639  1.000000  0.202905  0.045582  0.667869  0.139467
# runtime  0.231672  0.202905  1.000000  0.398840  0.287150  0.107902
# score   -0.027868  0.045582  0.398840  1.000000  0.392199  0.103598
# votes    0.616419  0.667869  0.287150  0.392199  1.000000  0.485588
# year     0.300553  0.139467  0.107902  0.103598  0.485588  1.000000

# %%
#visualize correlation matrix
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')
plt.show()

# %%
# company vs gross correlations
df_copy = df
for col_names in df_copy.columns:
    if df_copy[col_names].dtype=='object':
        df_copy[col_names] = df_copy[col_names].astype('category') #converting string attr to categories
        df_copy[col_names] = df_copy[col_names].cat.codes  #pandas cat codes assign numeric codes to categories
df_copy.head()
# Out:
#          budget  company  country  director  genre      gross  name  rating  \
# 6380  245000000     1428       54      1037      0  936662225  4679       7
# 5061  237000000     2062       53      1066      0  760507625   501       7
# 2420  200000000     2062       54      1066      6  658672302  6177       7
# 6391  150000000     2085       54       466      0  652270625  2721       7
# 5723  220000000     1491       54      1412      0  623357910  4995       7
#
#       released  runtime  score  star    votes  writer  year  CorrectYear
# 6380      2290      136    8.1   475   687192    2356  2015         1436
# 5061      1800      162    7.8  2084   954412    1629  2009          892
# 2420       910      194    7.8  1444   862554    1629  1997         2305
# 6391      2247      124    7.0   404   469200    3310  2015         1388
# 5723      1987      143    8.1  2001  1064633    2145  2012         1098

# %%
#visualize correlation matrix for strings data as well
correlation_matrix_full = df_copy.corr(method='pearson')
sns.heatmap(correlation_matrix_full,annot=True)
plt.title('Correlation Matrix')
plt.xlabel('Movies Features')
plt.ylabel('Movies Features')
plt.show()

# %%
df_copy.corr()
# Out:
#                budget   company   country  director     genre     gross  \
# budget       1.000000  0.187205  0.137635  0.011602 -0.346794  0.712196
# company      0.187205  1.000000  0.107950  0.004320 -0.068330  0.187220
# country      0.137635  0.107950  1.000000  0.003698 -0.042793  0.149988
# director     0.011602  0.004320  0.003698  1.000000 -0.027668 -0.011429
# genre       -0.346794 -0.068330 -0.042793 -0.027668  1.000000 -0.242676
# gross        0.712196  0.187220  0.149988 -0.011429 -0.242676  1.000000
# name         0.028712  0.018098  0.025020  0.001905  0.018062  0.022768
# rating      -0.119660 -0.062250  0.057979  0.021926  0.100960 -0.135538
# released     0.276635  0.027898 -0.062609  0.001440 -0.039179  0.178564
# runtime      0.268226  0.033058 -0.081796  0.026779 -0.041357  0.224579
# score        0.042145 -0.010426 -0.174414  0.017130  0.056234  0.165693
# star        -0.015061 -0.003160 -0.014566  0.039813  0.008140  0.008382
# ...

# %%
#display attr with high correlations
#called unstacking 
correlation_mat = df_copy.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.187205
#              country        0.137635
#              director       0.011602
#              genre         -0.346794
#              gross          0.712196
#              name           0.028712
#              rating        -0.119660
#              released       0.276635
#              runtime        0.268226
#              score          0.042145
#              star          -0.015061
#              votes          0.503924
#              writer        -0.015611
#              year           0.291009
#              CorrectYear    0.274820
# company      budget         0.187205
#              company        1.000000
#              country        0.107950
#              director       0.004320
#              genre         -0.068330
#              gross          0.187220
#              name           0.018098
#              rating        -0.062250
#              released       0.027898
# ...

# %%
#results: movies with higher budgets have higher revenues & those with high number of votes are also high correlated with gross
high_corr = corr_pairs[corr_pairs > 0.5]
high_corr.sort_values()
# Out:
# budget       votes          0.503924
# votes        budget         0.503924
# gross        votes          0.662457
# votes        gross          0.662457
# budget       gross          0.712196
# gross        budget         0.712196
# released     year           0.996187
# year         released       0.996187
#              CorrectYear    0.996229
# CorrectYear  year           0.996229
#              released       0.999389
# released     CorrectYear    0.999389
# year         year           1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# budget       budget         1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# ...
